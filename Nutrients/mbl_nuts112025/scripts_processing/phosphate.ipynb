# %%
# PO4

# %%
library(ggplot2)
library(tidyverse)

# %%
getwd()
# Out:
# [1] "/Users/brookesienkiewicz/Documents/sctld/Nutrients/mbl_nuts"

# %%
metadata<-read.csv('metadata/samples_kinda_filtered.csv')

# %%
po4<-read.csv('po4_concentrations.csv')

# %%
po4
# Out:
#     Date   T  Sample Rack.position Cup.Number Sample.ID  Analyte.Name
# 1             NA     NA            S10        20NO2      PO4
# 2             NA     NA            S2         20N/8P     PO4
# 3             NA     NA            S1         30N/12P    PO4
# 4             NA     NA            S1         30N/12P    PO4
# 5             NA     NA            S2         20N/8P     PO4
# 6             NA     NA            S2         20N/8P     PO4
# 7             NA     NA            S3         10N/4P     PO4
# 8             NA     NA            S3         10N/4P     PO4
# 9             NA     NA            S10        20NO2      PO4
# 10            NA     NA            S2         20N/8P     PO4
# 11            NA     NA            S4         5N/2P      PO4
# 12            NA     NA            S4         5N/2P      PO4
# 13            NA     NA            S5         2N/0.8P    PO4
# 14            NA     NA            S5         2N/0.8P    PO4
# 15            NA     NA            S6         1N/0.4P    PO4
# 16            NA     NA            S6         1N/0.4P    PO4
# 17            NA     NA            S7         0.5N/0.2P  PO4
# 18            NA     NA            S7         0.5N/0.2P  PO4
# 19            NA     NA            S8         0.25N/0.1P PO4
# 20            NA     NA            S8         0.25N/0.1P PO4
# 21            NA     NA            S9         Saline     PO4
# 22            NA     NA            S9         Saline     PO4
# 23            NA     NA            S9         saline     PO4
# 24            NA     NA            S9         saline     PO4
# 25            NA     NA            S9         saline     PO4
# 26            NA     NA            S9         saline     PO4
# 27            NA     NA            S9         saline     PO4
# 28            NA     NA            S9         saline     PO4
# 29            NA     NA            S10        20NO2      PO4
# 30            NA     NA            S2         20N/8P     PO4
# ⋮   ⋮      ⋮  ⋮      ⋮             ⋮          ⋮          ⋮
# 133 Jun-25 T1 579    84            84         Sample 084 PO4
# 134 Jun-25 T1 586    85            85         Sample 085 PO4
# 135 Jun-25 T1 587    86            86         Sample 086 PO4
# 136 Jun-25 T1 588    87            87         Sample 087 PO4
# 137 Jun-25 T2 598    88            88         Sample 088 PO4
# 138 Jun-25 T2 599    89            89         Sample 089 PO4
# 139 Jun-25 T2 608    90            90         Sample 090 PO4
# 140 Jun-25 T2 610     1            91         Sample 091 PO4
# 141 Jun-25 T3 616     2            92         Sample 092 PO4
# 142 Jun-25 T3 620     3            93         Sample 093 PO4
# 143 Jun-25 T3 621     4            94         Sample 094 PO4
# 144 Jun-25 T3 625     5            95         Sample 095 PO4
# 145 Jun-25 T3 626     6            96         Sample 096 PO4
# 146 Jun-25 T5 636     7            97         Sample 097 PO4
# 147 Jun-25 T5 640     8            98         Sample 098 PO4
# 148 Jun-25 T5 641     9            99         Sample 099 PO4
# 149            NA    NA            S10        20NO2      PO4
# 150            NA    NA            S2         20N/8P     PO4
# 151            NA    NA            S9         Saline     PO4
# 152 Jun-25 T5 642    10            100        Sample 100 PO4
# 153 Jun-25 T5 646    11            101        Sample 101 PO4
# 154 Jun-25 T6 657    12            102        Sample 102 PO4
# 155 Jun-25 T6 658    13            103        Sample 103 PO4
# 156 Jun-25 T6 660    14            104        Sample 104 PO4
# 157 Jun-25 T6 667    15            105        Sample 105 PO4
# 158 Jun-25 T6 668    16            106        Sample 106 PO4
# 159 Aug-24 T6 487    17            107        Sample 107 PO4
# 160            NA    NA            S10        20NO2      PO4
# 161            NA    NA            S2         20N/8P     PO4
# 162            NA    NA            S9         Saline     PO4
#     Determined.Conc. Conc.x.ADF
# 1           NA        0.0000
# 2           NA        0.0000
# 3    0.0000000       12.0000
# 4    0.0000000       12.0000
# 5    0.0000000        8.0000
# 6    0.0000000        8.0000
# 7    0.0000000        4.0000
# 8    0.0000000        4.0000
# 9           NA       -0.2280
# 10          NA        8.0000
# 11   2.0003770        2.0000
# 12   2.0305330        2.0000
# 13   0.8366830        0.8000
# 14   0.8191226        0.8000
# 15   0.4055843        0.4000
# 16   0.4136851        0.4000
# 17   0.1957225        0.2000
# 18   0.1739252        0.2000
# 19   0.0995000        0.1000
# 20   0.0601000        0.1000
# 21  -0.0533000        0.0000
# 22  -0.0432615        0.0000
# 23          NA       -0.0779
# 24          NA       -0.0615
# 25          NA       -0.0854
# 26          NA       -0.0468
# 27          NA       -0.0510
# 28          NA       -0.0266
# 29          NA       -0.0792
# 30          NA        7.9400
# ⋮   ⋮                ⋮
# 133 NA                0.03710
# 134 NA                0.01350
# 135 NA                0.06110
# 136 NA                0.02530
# 137 NA                0.06550
# 138 NA                0.01000
# 139 NA                0.02660
# 140 NA               -0.00342
# 141 NA                0.04040
# 142 NA                0.04340
# 143 NA                0.02330
# 144 NA                0.08600
# 145 NA                0.07680
# 146 NA                0.01890
# 147 NA                0.06780
# 148 NA                0.03980
# 149 NA               -0.00927
# 150 NA                7.97000
# 151 NA                0.01620
# 152 NA                0.03760
# 153 NA                0.03770
# 154 NA                0.08630
# 155 NA                0.00471
# 156 NA                0.16500
# 157 NA                0.04540
# 158 NA                0.00604
# 159 NA                0.07310
# 160 NA               -0.02410
# 161 NA                7.97000
# 162 NA                0.03340

# %%
# plot stnd curve ---------------------------------------------------------------

# %%
# get standards - pull out samples with 'S'

# %%
stnds<-po4 %>% 
    filter(str_detect(Cup.Number, 'S')) %>%
    # remove S10 - only used in N analysis
    filter(!Cup.Number == 'S10') %>%
    filter(!is.na(Determined.Conc.)) %>%
    # remove 30 bc for some reason its 0 -> maybe I didn't make that one?
    filter(!Cup.Number == 'S1')

# %%
# arrange in order of concentration (reverse order)
stnds<-stnds %>%
    arrange(desc(Cup.Number))
stnds
# Out:
#    Date T Sample Rack.position Cup.Number Sample.ID  Analyte.Name
# 1         NA     NA            S9         Saline     PO4
# 2         NA     NA            S9         Saline     PO4
# 3         NA     NA            S8         0.25N/0.1P PO4
# 4         NA     NA            S8         0.25N/0.1P PO4
# 5         NA     NA            S7         0.5N/0.2P  PO4
# 6         NA     NA            S7         0.5N/0.2P  PO4
# 7         NA     NA            S6         1N/0.4P    PO4
# 8         NA     NA            S6         1N/0.4P    PO4
# 9         NA     NA            S5         2N/0.8P    PO4
# 10        NA     NA            S5         2N/0.8P    PO4
# 11        NA     NA            S4         5N/2P      PO4
# 12        NA     NA            S4         5N/2P      PO4
# 13        NA     NA            S3         10N/4P     PO4
# 14        NA     NA            S3         10N/4P     PO4
# 15        NA     NA            S2         20N/8P     PO4
# 16        NA     NA            S2         20N/8P     PO4
#    Determined.Conc. Conc.x.ADF
# 1  -0.0533000       0.0
# 2  -0.0432615       0.0
# 3   0.0995000       0.1
# 4   0.0601000       0.1
# 5   0.1957225       0.2
# 6   0.1739252       0.2
# 7   0.4055843       0.4
# 8   0.4136851       0.4
# 9   0.8366830       0.8
# 10  0.8191226       0.8
# 11  2.0003770       2.0
# 12  2.0305330       2.0
# 13  0.0000000       4.0
# 14  0.0000000       4.0
# 15  0.0000000       8.0
# 16  0.0000000       8.0

# %%
# predicted
# take the concentration from Sample.ID
stnds<-stnds %>%
    mutate(predicted.conc = as.numeric(str_extract(Sample.ID, "(?<=/)\\d*\\.?\\d+(?=P)"))) %>%
    # change NA to 0 for saline (serves as the 0/blank)
    mutate(predicted.conc = if_else(
        Sample.ID == "Saline",
        0,
        predicted.conc 
    ))
head(stnds)
# Out:
#   Date T Sample Rack.position Cup.Number Sample.ID  Analyte.Name
# 1        NA     NA            S9         Saline     PO4
# 2        NA     NA            S9         Saline     PO4
# 3        NA     NA            S8         0.25N/0.1P PO4
# 4        NA     NA            S8         0.25N/0.1P PO4
# 5        NA     NA            S7         0.5N/0.2P  PO4
# 6        NA     NA            S7         0.5N/0.2P  PO4
#   Determined.Conc. Conc.x.ADF predicted.conc
# 1 -0.0533000       0.0        0.0
# 2 -0.0432615       0.0        0.0
# 3  0.0995000       0.1        0.1
# 4  0.0601000       0.1        0.1
# 5  0.1957225       0.2        0.2
# 6  0.1739252       0.2        0.2

# %%
# plot stnd curve - predicted vs actual since we don't have raw ODs
# x-axis predicted concentration
# y-axis calculated concentration

# %%
# replace concentration -> use determined conc when possible, but if not use other column 
stnds<-stnds %>%
    mutate(conc = if_else(
        Determined.Conc. >0,
        Determined.Conc., 
        Conc.x.ADF))

# %%
model <- lm(conc ~ predicted.conc, data = stnds)

# 2. Extract the R^2 value
r_squared <- summary(model)$r.squared
r_squared
# Out:
# [1] 0.9999538

# %%
ggplot(data = stnds, aes(x = predicted.conc, y = conc))+
    geom_point() +
    geom_smooth(method = "lm", linetype = "dashed")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# samples ------------------------------------------------------------

# %%
# keep only actual samples
samples_po4<-po4%>%
    filter(!is.na(Sample))

# %%
# convert date format
unique(samples_po4$Date)
samples_po4<-samples_po4 %>%
    mutate(date=as.Date(paste0("01-",samples_po4$Date), format = "%d-%b-%y"))
class(samples_po4$date)
# Out:
# [1] "Jan-24" "May-24" "Jun-24" "Aug-24" "Jun-25"
# [1] "Date"

# %%
samples_po4 %>%
    filter(is.na(date))
# Out:
#      Date T Sample Rack.position Cup.Number Sample.ID Analyte.Name
#      Determined.Conc. Conc.x.ADF date

# %%
unique(samples_po4$date)
# Out:
# [1] "2024-01-01" "2024-05-01" "2024-06-01" "2024-08-01" "2025-06-01"

# %%
# plot conc by date 
ggplot(samples_po4, aes(x = date, y = Conc.x.ADF))+
    geom_point()+
    scale_x_date(breaks = unique(samples_po4$date))
# Out:
# plot without title

# %%
#### metadata -----------------------------------------------------------------------------

# %%
# sample IDs are already on po4 output 
# combine with site info 

# add meta columns to sample df 
    # change format of Transect and sample ID on metadata
metadata<-metadata%>%
    mutate(T=paste0('T',transect))%>%
    rename(Sample=nutrient_sample_) %>%
    mutate(Sample = str_replace(Sample, 'N',''))%>%
    mutate(Sample = str_replace(Sample, 'filter','0')) %>%
        # idk why 0 won't convert to numeric -> its converting to NA but whatever, that sample should only be present in CHLA analysis anyway 
    mutate(Sample = as.numeric(Sample)) %>%
    #change date format 
    mutate(date = as.Date(Date))
# Out:
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `Sample = as.numeric(Sample)`.
# Caused by warning:
# ! NAs introduced by coercion”

# %%
# get list of samples that were labelled incorrectly 
wrong_label<-metadata %>%
    filter(str_detect(notes, 'label'))
samples_to_fix<-unique(wrong_label$Sample)
samples_to_fix
# Out:
#  [1] 18 17 15 16  8 14  3 12  2 13 62 83 64 81 68 82 70 80 23 36 24 37 27 40 31
# [26] 38 33 39

# %%
# pull out Transect it is currently labelled as 
# pull out transect it needs to be changed to (in samples_po4)

metadata<-metadata %>%
    mutate(old_T = sapply(strsplit(metadata$notes,split = 'as '), "[",2)) %>%
    mutate(new_T = T)

# %%
samples_po4<-samples_po4 %>%
    left_join(metadata%>%select(date,new_T,old_T, Sample, meter, notes, monthyear), by = 'Sample')

# %%
# update incorrectly labelled sample locations
samples_po4<-samples_po4 %>%
    mutate(T_copy = new_T)

# view where it has been changed 
samples_po4 %>%
    filter(T != T_copy)
# Out:
#    Date   T  Sample Rack.position Cup.Number Sample.ID  Analyte.Name
# 1  Jan-24 T1   2     1            1          Sample 001 PO4
# 2  Jan-24 T1   3     2            2          Sample 002 PO4
# 3  Jan-24 T1   8     3            3          Sample 003 PO4
# 4  Jan-24 T1  15     4            4          Sample 004 PO4
# 5  Jan-24 T1  18     5            5          Sample 005 PO4
# 6  Jan-24 T2  23     6            6          Sample 006 PO4
# 7  Jan-24 T2  24     7            7          Sample 007 PO4
# 8  Jan-24 T2  27     8            8          Sample 008 PO4
# 9  Jan-24 T2  31     9            9          Sample 009 PO4
# 10 Jan-24 T2  33    10            10         Sample 010 PO4
# 11 Jan-24 T5  62    16            16         Sample 016 PO4
# 12 Jan-24 T5  64    17            17         Sample 017 PO4
# 13 Jan-24 T5  70    18            18         Sample 018 PO4
# 14 May-24 T1 226    23            23         Sample 023 PO4
#    Determined.Conc. Conc.x.ADF date.x     date.y     new_T old_T meter
# 1  NA               0.0443     2024-01-01 2024-01-08 T5    T1    50
# 2  NA               0.0507     2024-01-01 2024-01-08 T5    T1    40
# 3  NA               0.0762     2024-01-01 2024-01-08 T5    T1    30
# 4  NA               0.0852     2024-01-01 2024-01-08 T5    T1    20
# 5  NA               0.0656     2024-01-01 2024-01-08 T5    T1    10
# 6  NA               0.0437     2024-01-01 2024-01-09 T1    T2    10
# 7  NA               0.1130     2024-01-01 2024-01-09 T1    T2    20
# 8  NA               0.1230     2024-01-01 2024-01-09 T1    T2    30
# 9  NA               0.0117     2024-01-01 2024-01-09 T1    T2    40
# 10 NA               0.0138     2024-01-01 2024-01-09 T1    T2    50
# 11 NA               0.1170     2024-01-01 2024-01-12 T2    T5    0
# 12 NA               0.0124     2024-01-01 2024-01-12 T2    T5    10
# 13 NA               0.0161     2024-01-01 2024-01-12 T2    T5    30
# 14 NA               0.0123     2024-05-01 2024-04-28 T5    NA    40
#    notes          monthyear T_copy
# 1  labelled as T1 Jan 2024  T5
# 2  labelled as T1 Jan 2024  T5
# 3  labelled as T1 Jan 2024  T5
# 4  labelled as T1 Jan 2024  T5
# 5  labelled as T1 Jan 2024  T5
# 6  labelled as T2 Jan 2024  T1
# 7  labelled as T2 Jan 2024  T1
# 8  labelled as T2 Jan 2024  T1
# 9  labelled as T2 Jan 2024  T1
# 10 labelled as T2 Jan 2024  T1
# 11 labelled as T5 Jan 2024  T2
# 12 labelled as T5 Jan 2024  T2
# 13 labelled as T5 Jan 2024  T2
# 14                Apr 2024  T5

# %%
# check for NAs 
samples_po4 %>%
    filter(is.na(T_copy))

# ...exclude for now idk where these came from -> need to check in data sheets 
excluded_samples<-samples_po4 %>%
    filter(is.na(T_copy))
samples_po4<-samples_po4 %>%
    filter(!is.na(T_copy))
# Out:
#   Date   T  Sample Rack.position Cup.Number Sample.ID  Analyte.Name
# 1 May-24 T5 269    38            38         Sample 038 PO4
# 2 Jun-24 T1 308    45            45         Sample 045 PO4
#   Determined.Conc. Conc.x.ADF date.x     date.y new_T old_T meter notes
# 1 NA               0.0432     2024-05-01 <NA>   NA    NA    NA    NA
# 2 NA               0.2280     2024-06-01 <NA>   NA    NA    NA    NA
#   monthyear T_copy
# 1 NA        NA
# 2 NA        NA

# %%
# filter columns 
samples_po4<-samples_po4 %>%
    select(-T,-old_T,-new_T,-Date) %>%
    rename(T = T_copy)

# %%
samples_po4 %>%
    filter(is.na(date.y))
# Out:
#      Sample Rack.position Cup.Number Sample.ID Analyte.Name Determined.Conc.
#      Conc.x.ADF date.x date.y meter notes monthyear T

# %%
# add location names 
samples_po4<-samples_po4 %>%
    mutate(site = case_when(
        T == 'T1' ~ 'CBC30N',
        T == 'T2' ~ 'SR30N',
        T == 'T3' ~ 'Lagoon',
        T == 'T5' ~ 'BB',
        T == 'T6' ~ 'Hangman'))

# %%
# blanks?
metadata %>%
    filter(str_detect(nutrient,'BLANK'))
# Out:
#   X   Date       country site   transect depthm meter syringe Sample
# 1 161 2025-05-30 BEL     CBC30N 1        NA     DI            93
# 2 167 2025-05-30 BEL     CBC30N 1        NA                    0
#   time_sampled time_processed nutrient     vol_filteredmL notes nitrate
# 1              13:55          FILTER BLANK 60                   8_27_25
# 2              13:55          FILTER BLANK 150
#   monthyear T  date       old_T new_T
# 1 Jun 2025  T1 2025-05-30 NA    T1
# 2 Jun 2025  T1 2025-05-30 NA    T1

# %%
# remove blank
samples_po4<-samples_po4 %>%
    filter(!Sample == 93)

# %%
# facet by location 
ggplot(samples_po4, aes(x = date.y, y = Conc.x.ADF))+
    geom_point()+
    facet_wrap(~ site)+
    scale_x_date(breaks = unique(samples_po4$date.y))+
    theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %%
# more variable than the N concentrations
#..but also much lower so possibly variation from low concentrations and difficulties reading in the lachat

# %%
# get avgs 
samples_po4 %>%
    group_by(site,date.y,monthyear) %>%
    summarise(n_mean = mean(Conc.x.ADF),
             sd = sd(Conc.x.ADF))
# Out:
# `summarise()` has grouped output by 'site', 'date.y'. You can override using
# the `.groups` argument.
#    site    date.y     monthyear n_mean     sd
# 1  BB      2024-01-08 Jan 2024  0.06440000 0.01706619
# 2  BB      2024-04-28 Apr 2024  0.01741833 0.01519584
# 3  BB      2024-06-22 Jun 2024  0.07957500 0.08489006
# 4  BB      2024-08-25 Aug 2024  0.07947500 0.02686961
# 5  BB      2025-06-01 Jun 2025  0.04036000 0.01752493
# 6  CBC30N  2024-01-09 Jan 2024  0.06104000 0.05363211
# 7  CBC30N  2024-04-25 Apr 2024  0.03662750 0.03983794
# 8  CBC30N  2024-06-21 Jun 2024  0.06962500 0.04113055
# 9  CBC30N  2024-08-21 Aug 2024  0.04837500 0.01848375
# 10 CBC30N  2025-05-30 Jun 2025  0.03714000 0.01875335
# 11 Hangman 2024-04-29 Apr 2024  0.03842000 0.03181441
# 12 Hangman 2024-08-26 Aug 2024  0.07830000 0.06836934
# 13 Hangman 2025-06-02 Jun 2025  0.06149000 0.06687192
# 14 Lagoon  2024-01-10 Jan 2024  0.02074000 0.02763083
# 15 Lagoon  2024-04-25 Apr 2024  0.03618000 0.03762967
# 16 Lagoon  2024-06-20 Jun 2024  0.09980000 0.07009804
# 17 Lagoon  2024-08-24 Aug 2024  0.07652000 0.07184600
# 18 Lagoon  2025-05-29 Jun 2025  0.05398000 0.02638014
# 19 SR30N   2024-01-12 Jan 2024  0.04850000 0.05935158
# 20 SR30N   2024-04-26 Apr 2024  0.00804750 0.02077464
# 21 SR30N   2024-06-21 Jun 2024  0.11195000 0.02901281
# 22 SR30N   2024-08-22 Aug 2024  0.08702500 0.04043310
# 23 SR30N   2025-05-31 Jun 2025  0.02467000 0.02986118

# %%
# variation within site within sample time point 
for (sites in unique(samples_po4$site)){
    x<-ggplot(samples_po4%>%filter(site==sites), aes(x = meter, y = Conc.x.ADF))+
        geom_point()+
        facet_wrap(~ date.y)+
        # scale_x_date(breaks = unique(samples_po4$meter))+
        labs(y = '[po4]',title = sites)+
        theme(axis.text.x = element_text(angle = 45, hjust = 1))
    print(x)
    }
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# get avgs 
samples_po4 %>%
    group_by(site,date.y,monthyear,meter) %>%
    summarise(n_mean = mean(Conc.x.ADF),
             sd = sd(Conc.x.ADF))
# Out:
# `summarise()` has grouped output by 'site', 'date.y', 'monthyear'. You can
# override using the `.groups` argument.
#    site   date.y     monthyear meter n_mean   sd
# 1  BB     2024-01-08 Jan 2024  10     0.06560         NA
# 2  BB     2024-01-08 Jan 2024  20     0.08520         NA
# 3  BB     2024-01-08 Jan 2024  30     0.07620         NA
# 4  BB     2024-01-08 Jan 2024  40     0.05070         NA
# 5  BB     2024-01-08 Jan 2024  50     0.04430         NA
# 6  BB     2024-04-28 Apr 2024  0      0.03050 0.01230366
# 7  BB     2024-04-28 Apr 2024  10     0.00539         NA
# 8  BB     2024-04-28 Apr 2024  20    -0.00208         NA
# 9  BB     2024-04-28 Apr 2024  30     0.02790         NA
# 10 BB     2024-04-28 Apr 2024  40     0.01230         NA
# 11 BB     2024-06-22 Jun 2024  0      0.01550         NA
# 12 BB     2024-06-22 Jun 2024  10     0.06600         NA
# 13 BB     2024-06-22 Jun 2024  20     0.03380         NA
# 14 BB     2024-06-22 Jun 2024  40     0.20300         NA
# 15 BB     2024-08-25 Aug 2024  0      0.06990         NA
# 16 BB     2024-08-25 Aug 2024  10     0.09190         NA
# 17 BB     2024-08-25 Aug 2024  20     0.04710         NA
# 18 BB     2024-08-25 Aug 2024  30     0.10900         NA
# 19 BB     2025-06-01 Jun 2025  0      0.03770         NA
# 20 BB     2025-06-01 Jun 2025  10     0.03760         NA
# 21 BB     2025-06-01 Jun 2025  20     0.03980         NA
# 22 BB     2025-06-01 Jun 2025  30     0.06780         NA
# 23 BB     2025-06-01 Jun 2025  40     0.01890         NA
# 24 CBC30N 2024-01-09 Jan 2024  10     0.04370         NA
# 25 CBC30N 2024-01-09 Jan 2024  20     0.11300         NA
# 26 CBC30N 2024-01-09 Jan 2024  30     0.12300         NA
# 27 CBC30N 2024-01-09 Jan 2024  40     0.01170         NA
# 28 CBC30N 2024-01-09 Jan 2024  50     0.01380         NA
# 29 CBC30N 2024-04-25 Apr 2024  0      0.02410         NA
# 30 CBC30N 2024-04-25 Apr 2024  10     0.09560         NA
# ⋮  ⋮      ⋮          ⋮         ⋮     ⋮        ⋮
# 69 Lagoon 2024-04-25 Apr 2024  40     0.05810         NA
# 70 Lagoon 2024-06-20 Jun 2024  10     0.16400         NA
# 71 Lagoon 2024-06-20 Jun 2024  20     0.03230         NA
# 72 Lagoon 2024-06-20 Jun 2024  30     0.17600         NA
# 73 Lagoon 2024-06-20 Jun 2024  40     0.09880         NA
# 74 Lagoon 2024-06-20 Jun 2024  50     0.02790         NA
# 75 Lagoon 2024-08-24 Aug 2024  0      0.06090         NA
# 76 Lagoon 2024-08-24 Aug 2024  10     0.04490         NA
# 77 Lagoon 2024-08-24 Aug 2024  20     0.01340         NA
# 78 Lagoon 2024-08-24 Aug 2024  30     0.13170 0.09659079
# 79 Lagoon 2025-05-29 Jun 2025  unk    0.05398 0.02638014
# 80 SR30N  2024-01-12 Jan 2024  0      0.11700         NA
# 81 SR30N  2024-01-12 Jan 2024  10     0.01240         NA
# 82 SR30N  2024-01-12 Jan 2024  30     0.01610         NA
# 83 SR30N  2024-04-26 Apr 2024  0      0.03130         NA
# 84 SR30N  2024-04-26 Apr 2024  10     0.00869         NA
# 85 SR30N  2024-04-26 Apr 2024  20     0.01140         NA
# 86 SR30N  2024-04-26 Apr 2024  30    -0.01920         NA
# 87 SR30N  2024-06-21 Jun 2024  0      0.08500         NA
# 88 SR30N  2024-06-21 Jun 2024  10     0.08880         NA
# 89 SR30N  2024-06-21 Jun 2024  20     0.13900         NA
# 90 SR30N  2024-06-21 Jun 2024  30     0.13500         NA
# 91 SR30N  2024-08-22 Aug 2024  0      0.07710         NA
# 92 SR30N  2024-08-22 Aug 2024  10     0.04650         NA
# 93 SR30N  2024-08-22 Aug 2024  20     0.08150         NA
# 94 SR30N  2024-08-22 Aug 2024  30     0.14300         NA
# 95 SR30N  2025-05-31 Jun 2025  0      0.06550         NA
# 96 SR30N  2025-05-31 Jun 2025  10     0.01000         NA
# 97 SR30N  2025-05-31 Jun 2025  20     0.02660         NA
# 98 SR30N  2025-05-31 Jun 2025  30    -0.00342         NA
