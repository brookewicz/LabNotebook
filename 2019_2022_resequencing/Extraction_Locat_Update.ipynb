# %%
# importing metagenomics tracker extraction locations to cbc sample

# %%
import pandas as pd

# %%
meta=pd.read_csv('//Users/brookesienkiewicz/Documents/sctld/SCTLD_samples/Sample_Data/Metagenomics_Tracker_Belize.csv',index_col=0)

# %%
samples=pd.read_csv('//Users/brookesienkiewicz/Documents/sctld/SCTLD_samples/Sample_Data/CBC_samples.csv',index_col=0)

# %%
# Get the common columns
common_cols = [col for col in meta.columns if col in samples.columns]

# Check if the common columns are identical
identical_cols = [col for col in common_cols if meta[col].equals(samples[col])]

print("Common columns:", common_cols)
print("Identical columns:", identical_cols)
# Out:
# Common columns: ['Notes', 'Sample_physical_location', 'Extraction_physical_location']
# Identical columns: []

# %%
meta.head()
# Out:
#                               Health_Status Starting_Weight Date_Extracted  \
# 052022_BEL_CBC_T2_45_PSTR   Diseased_Margin             181     10_10_2023
# 052022_BEL_CBC_T2_46_PSTR   Diseased_Tissue             162     10_10_2023
# 052022_BEL_CBC_T2_59_OFAV           Healthy             174      10_3_2023
# 042024_BEL_CBC_T1_925_PAST         Healthy            325.5      8_19_2024
# 052022_BEL_CBC_T2_72_OFAV           Healthy              75      10_3_2023
#
#                            Raw_ng_ul Date_Enriched Microbe_ng_ul  \
# 052022_BEL_CBC_T2_45_PSTR       22.8    10_17_2023           7.5
# 052022_BEL_CBC_T2_46_PSTR       63.9    10_17_2023          18.5
# 052022_BEL_CBC_T2_59_OFAV       73.7    10_16_2023          11.7
# 042024_BEL_CBC_T1_925_PAST      5.46     9_28_2024          1.57
# 052022_BEL_CBC_T2_72_OFAV       47.6      10_11_23          3.96
#
#                               Microbe_Location Microbe_clean_date/n  \
# ...

# %%
samples.head()
# Out:
#            Country Location CollectionDate Transect  TransectNum OldTagNum  \
# Month_year
# 122022         BEL      CBC        12/5/22   CURLEW            4       NaN
# 92023          BEL      CBC        9/25/23   CBC30N            1       NaN
# 92023          BEL      CBC        9/25/23   CBC30N            1       NaN
# 92023          BEL      CBC        9/25/23   CBC30N            1       NaN
# 92023          BEL      CBC        9/25/23   CBC30N            1       NaN
#
#            NewTagNum Species Time_sampled Time_processed    Sample_type  \
# Month_year
# 122022            77    OFAV          NaN            NaN    Core_frozen
# 92023              2    PAST          NaN            NaN  Core_RNAlater
# 92023             21    PAST          NaN            NaN  Core_RNAlater
# 92023              3    SSID          NaN            NaN  Core_RNAlater
# 92023             24    MCAV          NaN            NaN  Core_RNAlater
#
#            SampleNum Health_status   Sampling_notes  \
# ...

# %%
samples['Extraction_physical_location'].unique()
# Out:
# array([nan, 'UML_NARWHAL_R2_B11', 'UML_NARWHAL_R2_B3', 'DNA_extracted',
#        '?'], dtype=object)

# %%
# make sample IDs the row names in cbc samples to match metagenomics tracker
#samples.set_index('Tubelabel_species', inplace=True)

# %%
samples.head()
# Out:
#            Country Location CollectionDate Transect  TransectNum OldTagNum  \
# Month_year
# 122022         BEL      CBC        12/5/22   CURLEW            4       NaN
# 92023          BEL      CBC        9/25/23   CBC30N            1       NaN
# 92023          BEL      CBC        9/25/23   CBC30N            1       NaN
# 92023          BEL      CBC        9/25/23   CBC30N            1       NaN
# 92023          BEL      CBC        9/25/23   CBC30N            1       NaN
#
#            NewTagNum Species Time_sampled Time_processed    Sample_type  \
# Month_year
# 122022            77    OFAV          NaN            NaN    Core_frozen
# 92023              2    PAST          NaN            NaN  Core_RNAlater
# 92023             21    PAST          NaN            NaN  Core_RNAlater
# 92023              3    SSID          NaN            NaN  Core_RNAlater
# 92023             24    MCAV          NaN            NaN  Core_RNAlater
#
#            SampleNum Health_status   Sampling_notes  \
# ...

# %%
# Update the 'Extraction_physical_location' column in samples
samples['Extraction_physical_location'] = samples['Tubelabel_species'].map(meta['Extraction_physical_location']).fillna(samples['Extraction_physical_location'])

# %%
samples['Extraction_physical_location'].unique()
# Out:
# array([nan, 'UML_NARWHAL_R2_B11', 'UML_NARWHAL_R2_B3',
#        'UML_NARWHAL_R2_B26', 'UML_NARWHAL_R2_B29', 'penguin',
#        'DNA_extracted'], dtype=object)

# %%
import os
os.chdir('/Users/brookesienkiewicz/Documents/sctld/SCTLD_samples/Sample_Data/')

# %%
samples.to_csv('CBC_samples.csv')
